# %%
import numpy as np
import pandas as pd

# %%
# !pip install music21
# Out:
# Requirement already satisfied: music21 in /usr/local/lib/python3.7/dist-packages (5.5.0)

# %%
# Creating a function to read midi file 
from music21 import *

def midi_read(file):

  print("Reading file:",file)
  notes=[]
  notes_to_parse= None
  midi = converter.parse(file)
  
  s2 = instrument.partitionByInstrument(midi)

  for part in s2.parts:
  
      if 'Piano' in str(part): 
      
          notes_to_parse = part.recurse() 

          for element in notes_to_parse:
              
              if isinstance(element, note.Note):
                  notes.append(str(element.pitch))

              elif isinstance(element, chord.Chord):
                  notes.append('.'.join(str(n) for n in element.normalOrder))

  return np.array(notes)

# %%
import os

#Array Processing
import numpy as np

#specify the path
path='/content/drive/MyDrive/schubert/'

#read all the filenames
files=[i for i in os.listdir(path) if i.endswith(".mid")]

#reading each midi file
notes_array = np.array([midi_read(path+i) for i in files])
# Out:
# Reading file: /content/drive/MyDrive/schubert/schu_143_3.mid
# Reading file: /content/drive/MyDrive/schubert/schu_143_2.mid
# Reading file: /content/drive/MyDrive/schubert/schu_143_1.mid
# Reading file: /content/drive/MyDrive/schubert/schumm-5.mid
# Reading file: /content/drive/MyDrive/schubert/schumm-6.mid
# Reading file: /content/drive/MyDrive/schubert/schumm-2.mid
# Reading file: /content/drive/MyDrive/schubert/schumm-3.mid
# Reading file: /content/drive/MyDrive/schubert/schumm-4.mid
# Reading file: /content/drive/MyDrive/schubert/schumm-1.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d960_4.mid
# Reading file: /content/drive/MyDrive/schubert/schuim-4.mid
# Reading file: /content/drive/MyDrive/schubert/schuim-3.mid
# Reading file: /content/drive/MyDrive/schubert/schuim-1.mid
# Reading file: /content/drive/MyDrive/schubert/schuim-2.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d960_3.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d960_2.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d960_1.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d760_4.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d760_3.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d760_1.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D935_4.mid
# Reading file: /content/drive/MyDrive/schubert/schub_d760_2.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D935_3.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D935_2.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D935_1.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D850_4.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D850_3.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D850_2.mid
# Reading file: /content/drive/MyDrive/schubert/schubert_D850_1.mid
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   del sys.path[0]

# %%
#converting 2D array into 1D array
notes_ = [element for note_ in notes_array for element in note_]

#No. of unique notes
unique_notes = list(set(notes_))
print(len(unique_notes))
# Out:
# 304

# %%
#importing library
from collections import Counter

#computing frequency of each note
freq = dict(Counter(notes_))

#library for visualiation
import matplotlib.pyplot as plt

#consider only the frequencies
no=[count for _,count in freq.items()]

#set the figure size
plt.figure(figsize=(5,5))

#plot
plt.hist(no)
plt.xlabel("notes")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# As most notes have a frequency above 50 keeping only those
frequent_notes = [note_ for note_, count in freq.items() if count>=50]
print(len(frequent_notes))
# Out:
# 167

# %%
new_music=[]

for notes in notes_array:
    temp=[]
    for note_ in notes:
        if note_ in frequent_notes:
            temp.append(note_)            
    new_music.append(temp)
    
new_music = np.array(new_music)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.

# %%
no_of_timesteps = 32
x = []
y = []

for note_ in new_music:
    for i in range(0, len(note_) - no_of_timesteps, 1):
        
        #preparing input and output sequences
        input_ = note_[i:i + no_of_timesteps]
        output = note_[i + no_of_timesteps]
        
        x.append(input_)
        y.append(output)
        
x=np.array(x)
y=np.array(y)

# %%
unique_x = list(set(x.ravel()))
x_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_x))

# %%
#preparing input sequences
x_seq=[]
for i in x:
    temp=[]
    for j in i:
        #assigning unique integer to every note
        temp.append(x_note_to_int[j])
    x_seq.append(temp)
    
x_seq = np.array(x_seq)

# %%
unique_y = list(set(y))
y_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_y)) 
y_seq=np.array([y_note_to_int[i] for i in y])

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(x_seq,y_seq,test_size=0.2,random_state=0)

# %%
from keras.layers import (Dense,Flatten,Conv1D,Embedding,MaxPool1D,Dropout,GlobalMaxPool1D)
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
# import keras.backend as K

# K.clear_session()
model = Sequential()
    
#embedding layer
model.add(Embedding(len(unique_x), 100, input_length=32,trainable=True)) 

model.add(Conv1D(64,3, padding='causal',activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
    
model.add(Conv1D(128,3,activation='relu',dilation_rate=2,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

model.add(Conv1D(256,3,activation='relu',dilation_rate=4,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
          
#model.add(Conv1D(256,5,activation='relu'))    
model.add(GlobalMaxPool1D())
    
model.add(Dense(256, activation='relu'))
model.add(Dense(len(unique_y), activation='softmax'))
    
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',metrics=['acc'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 32, 100)           16700
# _________________________________________________________________
# conv1d (Conv1D)              (None, 32, 64)            19264
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 64)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 16, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 128)           24704
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8, 128)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 8, 256)            98560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 256)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 4, 256)            0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dense_1 (Dense)              (None, 167)               42919
# =================================================================
# Total params: 267,939
# Trainable params: 267,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc=ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', save_best_only=True,verbose=1)

# %%
history = model.fit(np.array(x_tr),np.array(y_tr),batch_size=128,epochs=500, validation_data=(np.array(x_val),np.array(y_val)),verbose=1, callbacks=[mc])
# Out:
# Epoch 1/500
# 403/403 [==============================] - 20s 11ms/step - loss: 4.6075 - acc: 0.0337 - val_loss: 4.0412 - val_acc: 0.0938
#
# Epoch 00001: val_acc improved from -inf to 0.09384, saving model to best_model.h5
# Epoch 2/500
# 403/403 [==============================] - 3s 9ms/step - loss: 3.8341 - acc: 0.0996 - val_loss: 3.7896 - val_acc: 0.1243
#
# Epoch 00002: val_acc improved from 0.09384 to 0.12427, saving model to best_model.h5
# Epoch 3/500
# 403/403 [==============================] - 3s 9ms/step - loss: 3.6421 - acc: 0.1259 - val_loss: 3.6893 - val_acc: 0.1348
#
# Epoch 00003: val_acc improved from 0.12427 to 0.13475, saving model to best_model.h5
# Epoch 4/500
# 403/403 [==============================] - 3s 9ms/step - loss: 3.5063 - acc: 0.1434 - val_loss: 3.5963 - val_acc: 0.1517
#
# Epoch 00004: val_acc improved from 0.13475 to 0.15167, saving model to best_model.h5
# Epoch 5/500
# 403/403 [==============================] - 3s 9ms/step - loss: 3.3855 - acc: 0.1590 - val_loss: 3.5338 - val_acc: 0.1638
#
# Epoch 00005: val_acc improved from 0.15167 to 0.16378, saving model to best_model.h5
# Epoch 6/500
# 403/403 [==============================] - 3s 9ms/step - loss: 3.2807 - acc: 0.1715 - val_loss: 3.4241 - val_acc: 0.1742
#
# Epoch 00006: val_acc improved from 0.16378 to 0.17418, saving model to best_model.h5
# Epoch 7/500
# 403/403 [==============================] - 3s 8ms/step - loss: 3.2109 - acc: 0.1797 - val_loss: 3.3882 - val_acc: 0.1712
#
# Epoch 00007: val_acc did not improve from 0.17418
# Epoch 8/500
# 403/403 [==============================] - 3s 9ms/step - loss: 3.1512 - acc: 0.1878 - val_loss: 3.3200 - val_acc: 0.1788
#
# Epoch 00008: val_acc improved from 0.17418 to 0.17876, saving model to best_model.h5
# Epoch 9/500
# 403/403 [==============================] - 4s 9ms/step - loss: 3.0856 - acc: 0.1970 - val_loss: 3.3153 - val_acc: 0.1812
#
# Epoch 00009: val_acc improved from 0.17876 to 0.18117, saving model to best_model.h5
# Epoch 10/500
# 403/403 [==============================] - 4s 9ms/step - loss: 3.0344 - acc: 0.2035 - val_loss: 3.2276 - val_acc: 0.1927
#
# Epoch 00010: val_acc improved from 0.18117 to 0.19273, saving model to best_model.h5
# Epoch 11/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.9848 - acc: 0.2094 - val_loss: 3.2234 - val_acc: 0.1903
#
# Epoch 00011: val_acc did not improve from 0.19273
# Epoch 12/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.9419 - acc: 0.2113 - val_loss: 3.1842 - val_acc: 0.1986
#
# Epoch 00012: val_acc improved from 0.19273 to 0.19863, saving model to best_model.h5
# Epoch 13/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.9151 - acc: 0.2144 - val_loss: 3.1400 - val_acc: 0.2024
#
# Epoch 00013: val_acc improved from 0.19863 to 0.20236, saving model to best_model.h5
# Epoch 14/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.8566 - acc: 0.2231 - val_loss: 3.1538 - val_acc: 0.1973
#
# Epoch 00014: val_acc did not improve from 0.20236
# Epoch 15/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.8159 - acc: 0.2335 - val_loss: 3.1212 - val_acc: 0.2043
#
# Epoch 00015: val_acc improved from 0.20236 to 0.20430, saving model to best_model.h5
# Epoch 16/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.7886 - acc: 0.2406 - val_loss: 3.0940 - val_acc: 0.2119
#
# Epoch 00016: val_acc improved from 0.20430 to 0.21191, saving model to best_model.h5
# Epoch 17/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.7543 - acc: 0.2463 - val_loss: 3.0644 - val_acc: 0.2096
#
# Epoch 00017: val_acc did not improve from 0.21191
# Epoch 18/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.7308 - acc: 0.2468 - val_loss: 3.0597 - val_acc: 0.2054
#
# Epoch 00018: val_acc did not improve from 0.21191
# Epoch 19/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.7089 - acc: 0.2494 - val_loss: 3.0304 - val_acc: 0.2145
#
# Epoch 00019: val_acc improved from 0.21191 to 0.21447, saving model to best_model.h5
# Epoch 20/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.6665 - acc: 0.2527 - val_loss: 3.0138 - val_acc: 0.2171
#
# Epoch 00020: val_acc improved from 0.21447 to 0.21711, saving model to best_model.h5
# Epoch 21/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.6538 - acc: 0.2597 - val_loss: 3.0088 - val_acc: 0.2149
#
# Epoch 00021: val_acc did not improve from 0.21711
# Epoch 22/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.6405 - acc: 0.2593 - val_loss: 2.9898 - val_acc: 0.2181
#
# Epoch 00022: val_acc improved from 0.21711 to 0.21812, saving model to best_model.h5
# Epoch 23/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.6097 - acc: 0.2644 - val_loss: 2.9661 - val_acc: 0.2263
#
# Epoch 00023: val_acc improved from 0.21812 to 0.22627, saving model to best_model.h5
# Epoch 24/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.5868 - acc: 0.2738 - val_loss: 2.9809 - val_acc: 0.2236
#
# Epoch 00024: val_acc did not improve from 0.22627
# Epoch 25/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.5701 - acc: 0.2685 - val_loss: 2.9425 - val_acc: 0.2309
#
# Epoch 00025: val_acc improved from 0.22627 to 0.23092, saving model to best_model.h5
# Epoch 26/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.5478 - acc: 0.2790 - val_loss: 2.9444 - val_acc: 0.2328
#
# Epoch 00026: val_acc improved from 0.23092 to 0.23279, saving model to best_model.h5
# Epoch 27/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.5251 - acc: 0.2798 - val_loss: 2.9083 - val_acc: 0.2315
#
# Epoch 00027: val_acc did not improve from 0.23279
# Epoch 28/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.5055 - acc: 0.2829 - val_loss: 2.9288 - val_acc: 0.2329
#
# Epoch 00028: val_acc improved from 0.23279 to 0.23294, saving model to best_model.h5
# Epoch 29/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.5017 - acc: 0.2861 - val_loss: 2.8929 - val_acc: 0.2400
#
# Epoch 00029: val_acc improved from 0.23294 to 0.24001, saving model to best_model.h5
# Epoch 30/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.5005 - acc: 0.2862 - val_loss: 2.8965 - val_acc: 0.2361
#
# Epoch 00030: val_acc did not improve from 0.24001
# Epoch 31/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.4744 - acc: 0.2884 - val_loss: 2.9045 - val_acc: 0.2357
#
# Epoch 00031: val_acc did not improve from 0.24001
# Epoch 32/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.4682 - acc: 0.2948 - val_loss: 2.8912 - val_acc: 0.2423
#
# Epoch 00032: val_acc improved from 0.24001 to 0.24226, saving model to best_model.h5
# Epoch 33/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.4611 - acc: 0.2906 - val_loss: 2.8738 - val_acc: 0.2418
#
# Epoch 00033: val_acc did not improve from 0.24226
# Epoch 34/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.4426 - acc: 0.2971 - val_loss: 2.8686 - val_acc: 0.2426
#
# Epoch 00034: val_acc improved from 0.24226 to 0.24257, saving model to best_model.h5
# Epoch 35/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.4224 - acc: 0.3020 - val_loss: 2.8608 - val_acc: 0.2479
#
# Epoch 00035: val_acc improved from 0.24257 to 0.24792, saving model to best_model.h5
# Epoch 36/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.4284 - acc: 0.3018 - val_loss: 2.8615 - val_acc: 0.2444
#
# Epoch 00036: val_acc did not improve from 0.24792
# Epoch 37/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3946 - acc: 0.3056 - val_loss: 2.8520 - val_acc: 0.2456
#
# Epoch 00037: val_acc did not improve from 0.24792
# Epoch 38/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3807 - acc: 0.3094 - val_loss: 2.8444 - val_acc: 0.2495
#
# Epoch 00038: val_acc improved from 0.24792 to 0.24948, saving model to best_model.h5
# Epoch 39/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3808 - acc: 0.3089 - val_loss: 2.8505 - val_acc: 0.2480
#
# Epoch 00039: val_acc did not improve from 0.24948
# Epoch 40/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3689 - acc: 0.3110 - val_loss: 2.8296 - val_acc: 0.2475
#
# Epoch 00040: val_acc did not improve from 0.24948
# Epoch 41/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.3619 - acc: 0.3115 - val_loss: 2.8351 - val_acc: 0.2496
#
# Epoch 00041: val_acc improved from 0.24948 to 0.24955, saving model to best_model.h5
# Epoch 42/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3484 - acc: 0.3149 - val_loss: 2.8228 - val_acc: 0.2510
#
# Epoch 00042: val_acc improved from 0.24955 to 0.25095, saving model to best_model.h5
# Epoch 43/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3459 - acc: 0.3152 - val_loss: 2.8184 - val_acc: 0.2522
#
# Epoch 00043: val_acc improved from 0.25095 to 0.25219, saving model to best_model.h5
# Epoch 44/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.3312 - acc: 0.3192 - val_loss: 2.8154 - val_acc: 0.2525
#
# Epoch 00044: val_acc improved from 0.25219 to 0.25250, saving model to best_model.h5
# Epoch 45/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3347 - acc: 0.3190 - val_loss: 2.7949 - val_acc: 0.2582
#
# Epoch 00045: val_acc improved from 0.25250 to 0.25825, saving model to best_model.h5
# Epoch 46/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3284 - acc: 0.3190 - val_loss: 2.8119 - val_acc: 0.2556
#
# Epoch 00046: val_acc did not improve from 0.25825
# Epoch 47/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.3100 - acc: 0.3205 - val_loss: 2.7919 - val_acc: 0.2591
#
# Epoch 00047: val_acc improved from 0.25825 to 0.25910, saving model to best_model.h5
# Epoch 48/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.3171 - acc: 0.3204 - val_loss: 2.7868 - val_acc: 0.2617
#
# Epoch 00048: val_acc improved from 0.25910 to 0.26166, saving model to best_model.h5
# Epoch 49/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.3000 - acc: 0.3263 - val_loss: 2.7826 - val_acc: 0.2656
#
# Epoch 00049: val_acc improved from 0.26166 to 0.26562, saving model to best_model.h5
# Epoch 50/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.3063 - acc: 0.3259 - val_loss: 2.7914 - val_acc: 0.2646
#
# Epoch 00050: val_acc did not improve from 0.26562
# Epoch 51/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.2990 - acc: 0.3270 - val_loss: 2.7771 - val_acc: 0.2578
#
# Epoch 00051: val_acc did not improve from 0.26562
# Epoch 52/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.2849 - acc: 0.3264 - val_loss: 2.7870 - val_acc: 0.2627
#
# Epoch 00052: val_acc did not improve from 0.26562
# Epoch 53/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.2899 - acc: 0.3286 - val_loss: 2.7949 - val_acc: 0.2612
#
# Epoch 00053: val_acc did not improve from 0.26562
# Epoch 54/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2787 - acc: 0.3287 - val_loss: 2.7793 - val_acc: 0.2666
#
# Epoch 00054: val_acc improved from 0.26562 to 0.26655, saving model to best_model.h5
# Epoch 55/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2661 - acc: 0.3334 - val_loss: 2.7693 - val_acc: 0.2676
#
# Epoch 00055: val_acc improved from 0.26655 to 0.26756, saving model to best_model.h5
# Epoch 56/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.2701 - acc: 0.3325 - val_loss: 2.7755 - val_acc: 0.2631
#
# Epoch 00056: val_acc did not improve from 0.26756
# Epoch 57/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2630 - acc: 0.3345 - val_loss: 2.7590 - val_acc: 0.2693
#
# Epoch 00057: val_acc improved from 0.26756 to 0.26935, saving model to best_model.h5
# Epoch 58/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2598 - acc: 0.3330 - val_loss: 2.7582 - val_acc: 0.2717
#
# Epoch 00058: val_acc improved from 0.26935 to 0.27168, saving model to best_model.h5
# Epoch 59/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.2565 - acc: 0.3344 - val_loss: 2.7526 - val_acc: 0.2728
#
# Epoch 00059: val_acc improved from 0.27168 to 0.27284, saving model to best_model.h5
# Epoch 60/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2431 - acc: 0.3403 - val_loss: 2.7462 - val_acc: 0.2716
#
# Epoch 00060: val_acc did not improve from 0.27284
# Epoch 61/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.2561 - acc: 0.3362 - val_loss: 2.7594 - val_acc: 0.2656
#
# Epoch 00061: val_acc did not improve from 0.27284
# Epoch 62/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.2458 - acc: 0.3393 - val_loss: 2.7564 - val_acc: 0.2692
#
# Epoch 00062: val_acc did not improve from 0.27284
# Epoch 63/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2202 - acc: 0.3418 - val_loss: 2.7479 - val_acc: 0.2741
#
# Epoch 00063: val_acc improved from 0.27284 to 0.27408, saving model to best_model.h5
# Epoch 64/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2402 - acc: 0.3358 - val_loss: 2.7430 - val_acc: 0.2682
#
# Epoch 00064: val_acc did not improve from 0.27408
# Epoch 65/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2296 - acc: 0.3423 - val_loss: 2.7512 - val_acc: 0.2707
#
# Epoch 00065: val_acc did not improve from 0.27408
# Epoch 66/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2108 - acc: 0.3436 - val_loss: 2.7335 - val_acc: 0.2726
#
# Epoch 00066: val_acc did not improve from 0.27408
# Epoch 67/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2285 - acc: 0.3378 - val_loss: 2.7260 - val_acc: 0.2796
#
# Epoch 00067: val_acc improved from 0.27408 to 0.27959, saving model to best_model.h5
# Epoch 68/500
# 403/403 [==============================] - 4s 10ms/step - loss: 2.2056 - acc: 0.3430 - val_loss: 2.7335 - val_acc: 0.2747
#
# Epoch 00068: val_acc did not improve from 0.27959
# Epoch 69/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2085 - acc: 0.3446 - val_loss: 2.7294 - val_acc: 0.2782
#
# Epoch 00069: val_acc did not improve from 0.27959
# Epoch 70/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1983 - acc: 0.3477 - val_loss: 2.7376 - val_acc: 0.2765
#
# Epoch 00070: val_acc did not improve from 0.27959
# Epoch 71/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.2049 - acc: 0.3476 - val_loss: 2.7237 - val_acc: 0.2763
#
# Epoch 00071: val_acc did not improve from 0.27959
# Epoch 72/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1879 - acc: 0.3510 - val_loss: 2.7164 - val_acc: 0.2755
#
# Epoch 00072: val_acc did not improve from 0.27959
# Epoch 73/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1890 - acc: 0.3489 - val_loss: 2.7330 - val_acc: 0.2771
#
# Epoch 00073: val_acc did not improve from 0.27959
# Epoch 74/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1815 - acc: 0.3490 - val_loss: 2.7350 - val_acc: 0.2761
#
# Epoch 00074: val_acc did not improve from 0.27959
# Epoch 75/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1927 - acc: 0.3509 - val_loss: 2.7278 - val_acc: 0.2767
#
# Epoch 00075: val_acc did not improve from 0.27959
# Epoch 76/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1875 - acc: 0.3483 - val_loss: 2.7226 - val_acc: 0.2796
#
# Epoch 00076: val_acc did not improve from 0.27959
# Epoch 77/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1668 - acc: 0.3554 - val_loss: 2.7254 - val_acc: 0.2761
#
# Epoch 00077: val_acc did not improve from 0.27959
# Epoch 78/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1805 - acc: 0.3509 - val_loss: 2.7239 - val_acc: 0.2817
#
# Epoch 00078: val_acc improved from 0.27959 to 0.28169, saving model to best_model.h5
# Epoch 79/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1691 - acc: 0.3512 - val_loss: 2.7189 - val_acc: 0.2843
#
# Epoch 00079: val_acc improved from 0.28169 to 0.28425, saving model to best_model.h5
# Epoch 80/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1603 - acc: 0.3544 - val_loss: 2.7307 - val_acc: 0.2814
#
# Epoch 00080: val_acc did not improve from 0.28425
# Epoch 81/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1732 - acc: 0.3516 - val_loss: 2.7089 - val_acc: 0.2853
#
# Epoch 00081: val_acc improved from 0.28425 to 0.28534, saving model to best_model.h5
# Epoch 82/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1647 - acc: 0.3528 - val_loss: 2.7122 - val_acc: 0.2839
#
# Epoch 00082: val_acc did not improve from 0.28534
# Epoch 83/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1605 - acc: 0.3551 - val_loss: 2.7160 - val_acc: 0.2822
#
# Epoch 00083: val_acc did not improve from 0.28534
# Epoch 84/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1606 - acc: 0.3557 - val_loss: 2.7054 - val_acc: 0.2853
#
# Epoch 00084: val_acc did not improve from 0.28534
# Epoch 85/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1612 - acc: 0.3544 - val_loss: 2.7112 - val_acc: 0.2839
#
# Epoch 00085: val_acc did not improve from 0.28534
# Epoch 86/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1605 - acc: 0.3570 - val_loss: 2.7094 - val_acc: 0.2834
#
# Epoch 00086: val_acc did not improve from 0.28534
# Epoch 87/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1554 - acc: 0.3564 - val_loss: 2.7130 - val_acc: 0.2853
#
# Epoch 00087: val_acc did not improve from 0.28534
# Epoch 88/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1486 - acc: 0.3581 - val_loss: 2.7139 - val_acc: 0.2843
#
# Epoch 00088: val_acc did not improve from 0.28534
# Epoch 89/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1562 - acc: 0.3546 - val_loss: 2.7105 - val_acc: 0.2834
#
# Epoch 00089: val_acc did not improve from 0.28534
# Epoch 90/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1420 - acc: 0.3594 - val_loss: 2.7000 - val_acc: 0.2905
#
# Epoch 00090: val_acc improved from 0.28534 to 0.29054, saving model to best_model.h5
# Epoch 91/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1309 - acc: 0.3603 - val_loss: 2.6986 - val_acc: 0.2871
#
# Epoch 00091: val_acc did not improve from 0.29054
# Epoch 92/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1364 - acc: 0.3583 - val_loss: 2.7008 - val_acc: 0.2908
#
# Epoch 00092: val_acc improved from 0.29054 to 0.29085, saving model to best_model.h5
# Epoch 93/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1220 - acc: 0.3636 - val_loss: 2.7002 - val_acc: 0.2881
#
# Epoch 00093: val_acc did not improve from 0.29085
# Epoch 94/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1363 - acc: 0.3614 - val_loss: 2.6951 - val_acc: 0.2895
#
# Epoch 00094: val_acc did not improve from 0.29085
# Epoch 95/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1314 - acc: 0.3635 - val_loss: 2.6897 - val_acc: 0.2920
#
# Epoch 00095: val_acc improved from 0.29085 to 0.29201, saving model to best_model.h5
# Epoch 96/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1327 - acc: 0.3606 - val_loss: 2.6882 - val_acc: 0.2922
#
# Epoch 00096: val_acc improved from 0.29201 to 0.29217, saving model to best_model.h5
# Epoch 97/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1219 - acc: 0.3635 - val_loss: 2.6955 - val_acc: 0.2888
#
# Epoch 00097: val_acc did not improve from 0.29217
# Epoch 98/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1182 - acc: 0.3636 - val_loss: 2.6906 - val_acc: 0.2905
#
# Epoch 00098: val_acc did not improve from 0.29217
# Epoch 99/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1109 - acc: 0.3666 - val_loss: 2.7023 - val_acc: 0.2810
#
# Epoch 00099: val_acc did not improve from 0.29217
# Epoch 100/500
# 403/403 [==============================] - 3s 8ms/step - loss: 2.1085 - acc: 0.3640 - val_loss: 2.6924 - val_acc: 0.2888
#
# Epoch 00100: val_acc did not improve from 0.29217
# Epoch 101/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1173 - acc: 0.3633 - val_loss: 2.7001 - val_acc: 0.2897
#
# Epoch 00101: val_acc did not improve from 0.29217
# Epoch 102/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1168 - acc: 0.3618 - val_loss: 2.6980 - val_acc: 0.2867
#
# Epoch 00102: val_acc did not improve from 0.29217
# Epoch 103/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1102 - acc: 0.3664 - val_loss: 2.7029 - val_acc: 0.2908
#
# Epoch 00103: val_acc did not improve from 0.29217
# Epoch 104/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1066 - acc: 0.3665 - val_loss: 2.6823 - val_acc: 0.2939
#
# Epoch 00104: val_acc improved from 0.29217 to 0.29388, saving model to best_model.h5
# Epoch 105/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1019 - acc: 0.3672 - val_loss: 2.6776 - val_acc: 0.2933
#
# Epoch 00105: val_acc did not improve from 0.29388
# Epoch 106/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.1126 - acc: 0.3656 - val_loss: 2.6833 - val_acc: 0.2935
#
# Epoch 00106: val_acc did not improve from 0.29388
# Epoch 107/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0965 - acc: 0.3700 - val_loss: 2.6973 - val_acc: 0.2896
#
# Epoch 00107: val_acc did not improve from 0.29388
# Epoch 108/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0929 - acc: 0.3683 - val_loss: 2.6945 - val_acc: 0.2880
#
# Epoch 00108: val_acc did not improve from 0.29388
# Epoch 109/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1115 - acc: 0.3662 - val_loss: 2.6802 - val_acc: 0.2940
#
# Epoch 00109: val_acc improved from 0.29388 to 0.29403, saving model to best_model.h5
# Epoch 110/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0961 - acc: 0.3704 - val_loss: 2.6848 - val_acc: 0.2910
#
# Epoch 00110: val_acc did not improve from 0.29403
# Epoch 111/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.1011 - acc: 0.3677 - val_loss: 2.6879 - val_acc: 0.2933
#
# Epoch 00111: val_acc did not improve from 0.29403
# Epoch 112/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0847 - acc: 0.3686 - val_loss: 2.6873 - val_acc: 0.2899
#
# Epoch 00112: val_acc did not improve from 0.29403
# Epoch 113/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0869 - acc: 0.3696 - val_loss: 2.6860 - val_acc: 0.2963
#
# Epoch 00113: val_acc improved from 0.29403 to 0.29628, saving model to best_model.h5
# Epoch 114/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0893 - acc: 0.3727 - val_loss: 2.6769 - val_acc: 0.2929
#
# Epoch 00114: val_acc did not improve from 0.29628
# Epoch 115/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0886 - acc: 0.3729 - val_loss: 2.6761 - val_acc: 0.2997
#
# Epoch 00115: val_acc improved from 0.29628 to 0.29970, saving model to best_model.h5
# Epoch 116/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0926 - acc: 0.3685 - val_loss: 2.6926 - val_acc: 0.2924
#
# Epoch 00116: val_acc did not improve from 0.29970
# Epoch 117/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0849 - acc: 0.3724 - val_loss: 2.6715 - val_acc: 0.2954
#
# Epoch 00117: val_acc did not improve from 0.29970
# Epoch 118/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0730 - acc: 0.3756 - val_loss: 2.6676 - val_acc: 0.2999
#
# Epoch 00118: val_acc improved from 0.29970 to 0.29993, saving model to best_model.h5
# Epoch 119/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0741 - acc: 0.3747 - val_loss: 2.6738 - val_acc: 0.3004
#
# Epoch 00119: val_acc improved from 0.29993 to 0.30040, saving model to best_model.h5
# Epoch 120/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0723 - acc: 0.3774 - val_loss: 2.6731 - val_acc: 0.2960
#
# Epoch 00120: val_acc did not improve from 0.30040
# Epoch 121/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0809 - acc: 0.3710 - val_loss: 2.6693 - val_acc: 0.2956
#
# Epoch 00121: val_acc did not improve from 0.30040
# Epoch 122/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0772 - acc: 0.3729 - val_loss: 2.6679 - val_acc: 0.3003
#
# Epoch 00122: val_acc did not improve from 0.30040
# Epoch 123/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0764 - acc: 0.3700 - val_loss: 2.6662 - val_acc: 0.2995
#
# Epoch 00123: val_acc did not improve from 0.30040
# Epoch 124/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0646 - acc: 0.3742 - val_loss: 2.6649 - val_acc: 0.3039
#
# Epoch 00124: val_acc improved from 0.30040 to 0.30389, saving model to best_model.h5
# Epoch 125/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0763 - acc: 0.3773 - val_loss: 2.6644 - val_acc: 0.3001
#
# Epoch 00125: val_acc did not improve from 0.30389
# Epoch 126/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0813 - acc: 0.3741 - val_loss: 2.6630 - val_acc: 0.3024
#
# Epoch 00126: val_acc did not improve from 0.30389
# Epoch 127/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0665 - acc: 0.3736 - val_loss: 2.6659 - val_acc: 0.2992
#
# Epoch 00127: val_acc did not improve from 0.30389
# Epoch 128/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0723 - acc: 0.3705 - val_loss: 2.6722 - val_acc: 0.2978
#
# Epoch 00128: val_acc did not improve from 0.30389
# Epoch 129/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0563 - acc: 0.3788 - val_loss: 2.6598 - val_acc: 0.3037
#
# Epoch 00129: val_acc did not improve from 0.30389
# Epoch 130/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0452 - acc: 0.3794 - val_loss: 2.6628 - val_acc: 0.2978
#
# Epoch 00130: val_acc did not improve from 0.30389
# Epoch 131/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0454 - acc: 0.3793 - val_loss: 2.6692 - val_acc: 0.2975
#
# Epoch 00131: val_acc did not improve from 0.30389
# Epoch 132/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0702 - acc: 0.3783 - val_loss: 2.6773 - val_acc: 0.2960
#
# Epoch 00132: val_acc did not improve from 0.30389
# Epoch 133/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0541 - acc: 0.3789 - val_loss: 2.6586 - val_acc: 0.3025
#
# Epoch 00133: val_acc did not improve from 0.30389
# Epoch 134/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0509 - acc: 0.3792 - val_loss: 2.6487 - val_acc: 0.3007
#
# Epoch 00134: val_acc did not improve from 0.30389
# Epoch 135/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0518 - acc: 0.3769 - val_loss: 2.6613 - val_acc: 0.2989
#
# Epoch 00135: val_acc did not improve from 0.30389
# Epoch 136/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0412 - acc: 0.3813 - val_loss: 2.6598 - val_acc: 0.3010
#
# Epoch 00136: val_acc did not improve from 0.30389
# Epoch 137/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0596 - acc: 0.3795 - val_loss: 2.6617 - val_acc: 0.3022
#
# Epoch 00137: val_acc did not improve from 0.30389
# Epoch 138/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0438 - acc: 0.3826 - val_loss: 2.6563 - val_acc: 0.3062
#
# Epoch 00138: val_acc improved from 0.30389 to 0.30622, saving model to best_model.h5
# Epoch 139/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0403 - acc: 0.3826 - val_loss: 2.6723 - val_acc: 0.3028
#
# Epoch 00139: val_acc did not improve from 0.30622
# Epoch 140/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0400 - acc: 0.3844 - val_loss: 2.6728 - val_acc: 0.3002
#
# Epoch 00140: val_acc did not improve from 0.30622
# Epoch 141/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0492 - acc: 0.3806 - val_loss: 2.6682 - val_acc: 0.3014
#
# Epoch 00141: val_acc did not improve from 0.30622
# Epoch 142/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0419 - acc: 0.3770 - val_loss: 2.6647 - val_acc: 0.3040
#
# Epoch 00142: val_acc did not improve from 0.30622
# Epoch 143/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0445 - acc: 0.3802 - val_loss: 2.6640 - val_acc: 0.3018
#
# Epoch 00143: val_acc did not improve from 0.30622
# Epoch 144/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0264 - acc: 0.3883 - val_loss: 2.6731 - val_acc: 0.3009
#
# Epoch 00144: val_acc did not improve from 0.30622
# Epoch 145/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0408 - acc: 0.3820 - val_loss: 2.6547 - val_acc: 0.3007
#
# Epoch 00145: val_acc did not improve from 0.30622
# Epoch 146/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0331 - acc: 0.3850 - val_loss: 2.6567 - val_acc: 0.2985
#
# Epoch 00146: val_acc did not improve from 0.30622
# Epoch 147/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0214 - acc: 0.3864 - val_loss: 2.6564 - val_acc: 0.3071
#
# Epoch 00147: val_acc improved from 0.30622 to 0.30715, saving model to best_model.h5
# Epoch 148/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0406 - acc: 0.3801 - val_loss: 2.6665 - val_acc: 0.3025
#
# Epoch 00148: val_acc did not improve from 0.30715
# Epoch 149/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0387 - acc: 0.3810 - val_loss: 2.6593 - val_acc: 0.3041
#
# Epoch 00149: val_acc did not improve from 0.30715
# Epoch 150/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0253 - acc: 0.3858 - val_loss: 2.6467 - val_acc: 0.3017
#
# Epoch 00150: val_acc did not improve from 0.30715
# Epoch 151/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0369 - acc: 0.3831 - val_loss: 2.6568 - val_acc: 0.3037
#
# Epoch 00151: val_acc did not improve from 0.30715
# Epoch 152/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0371 - acc: 0.3845 - val_loss: 2.6562 - val_acc: 0.3065
#
# Epoch 00152: val_acc did not improve from 0.30715
# Epoch 153/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0312 - acc: 0.3865 - val_loss: 2.6589 - val_acc: 0.3006
#
# Epoch 00153: val_acc did not improve from 0.30715
# Epoch 154/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0161 - acc: 0.3873 - val_loss: 2.6658 - val_acc: 0.3049
#
# Epoch 00154: val_acc did not improve from 0.30715
# Epoch 155/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0198 - acc: 0.3882 - val_loss: 2.6533 - val_acc: 0.3079
#
# Epoch 00155: val_acc improved from 0.30715 to 0.30793, saving model to best_model.h5
# Epoch 156/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0099 - acc: 0.3876 - val_loss: 2.6561 - val_acc: 0.3025
#
# Epoch 00156: val_acc did not improve from 0.30793
# Epoch 157/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0173 - acc: 0.3865 - val_loss: 2.6413 - val_acc: 0.3075
#
# Epoch 00157: val_acc did not improve from 0.30793
# Epoch 158/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0158 - acc: 0.3880 - val_loss: 2.6571 - val_acc: 0.3035
#
# Epoch 00158: val_acc did not improve from 0.30793
# Epoch 159/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0258 - acc: 0.3858 - val_loss: 2.6410 - val_acc: 0.3101
#
# Epoch 00159: val_acc improved from 0.30793 to 0.31010, saving model to best_model.h5
# Epoch 160/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0224 - acc: 0.3887 - val_loss: 2.6569 - val_acc: 0.3080
#
# Epoch 00160: val_acc did not improve from 0.31010
# Epoch 161/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0111 - acc: 0.3869 - val_loss: 2.6585 - val_acc: 0.3061
#
# Epoch 00161: val_acc did not improve from 0.31010
# Epoch 162/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0162 - acc: 0.3881 - val_loss: 2.6664 - val_acc: 0.3032
#
# Epoch 00162: val_acc did not improve from 0.31010
# Epoch 163/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0272 - acc: 0.3831 - val_loss: 2.6531 - val_acc: 0.3057
#
# Epoch 00163: val_acc did not improve from 0.31010
# Epoch 164/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0156 - acc: 0.3883 - val_loss: 2.6607 - val_acc: 0.3035
#
# Epoch 00164: val_acc did not improve from 0.31010
# Epoch 165/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0082 - acc: 0.3871 - val_loss: 2.6535 - val_acc: 0.3085
#
# Epoch 00165: val_acc did not improve from 0.31010
# Epoch 166/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0101 - acc: 0.3898 - val_loss: 2.6524 - val_acc: 0.3056
#
# Epoch 00166: val_acc did not improve from 0.31010
# Epoch 167/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9919 - acc: 0.3925 - val_loss: 2.6549 - val_acc: 0.3053
#
# Epoch 00167: val_acc did not improve from 0.31010
# Epoch 168/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0014 - acc: 0.3896 - val_loss: 2.6627 - val_acc: 0.3089
#
# Epoch 00168: val_acc did not improve from 0.31010
# Epoch 169/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0107 - acc: 0.3871 - val_loss: 2.6551 - val_acc: 0.3028
#
# Epoch 00169: val_acc did not improve from 0.31010
# Epoch 170/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0064 - acc: 0.3891 - val_loss: 2.6550 - val_acc: 0.3088
#
# Epoch 00170: val_acc did not improve from 0.31010
# Epoch 171/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0141 - acc: 0.3871 - val_loss: 2.6444 - val_acc: 0.3078
#
# Epoch 00171: val_acc did not improve from 0.31010
# Epoch 172/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0014 - acc: 0.3911 - val_loss: 2.6480 - val_acc: 0.3049
#
# Epoch 00172: val_acc did not improve from 0.31010
# Epoch 173/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0065 - acc: 0.3888 - val_loss: 2.6514 - val_acc: 0.3087
#
# Epoch 00173: val_acc did not improve from 0.31010
# Epoch 174/500
# 403/403 [==============================] - 3s 9ms/step - loss: 2.0107 - acc: 0.3897 - val_loss: 2.6353 - val_acc: 0.3087
#
# Epoch 00174: val_acc did not improve from 0.31010
# Epoch 175/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9979 - acc: 0.3934 - val_loss: 2.6475 - val_acc: 0.3058
#
# Epoch 00175: val_acc did not improve from 0.31010
# Epoch 176/500
# 403/403 [==============================] - 3s 9ms/step - loss: 1.9994 - acc: 0.3931 - val_loss: 2.6563 - val_acc: 0.3068
#
# Epoch 00176: val_acc did not improve from 0.31010
# Epoch 177/500
# 403/403 [==============================] - 3s 9ms/step - loss: 1.9997 - acc: 0.3910 - val_loss: 2.6461 - val_acc: 0.3097
#
# Epoch 00177: val_acc did not improve from 0.31010
# Epoch 178/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9921 - acc: 0.3903 - val_loss: 2.6587 - val_acc: 0.3039
#
# Epoch 00178: val_acc did not improve from 0.31010
# Epoch 179/500
# 403/403 [==============================] - 3s 9ms/step - loss: 1.9962 - acc: 0.3901 - val_loss: 2.6575 - val_acc: 0.3062
#
# Epoch 00179: val_acc did not improve from 0.31010
# Epoch 180/500
# 403/403 [==============================] - 3s 9ms/step - loss: 1.9987 - acc: 0.3921 - val_loss: 2.6373 - val_acc: 0.3108
#
# Epoch 00180: val_acc improved from 0.31010 to 0.31080, saving model to best_model.h5
# Epoch 181/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9816 - acc: 0.3945 - val_loss: 2.6444 - val_acc: 0.3084
#
# Epoch 00181: val_acc did not improve from 0.31080
# Epoch 182/500
# 403/403 [==============================] - 3s 9ms/step - loss: 1.9917 - acc: 0.3968 - val_loss: 2.6485 - val_acc: 0.3090
#
# Epoch 00182: val_acc did not improve from 0.31080
# Epoch 183/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9964 - acc: 0.3939 - val_loss: 2.6523 - val_acc: 0.3136
#
# Epoch 00183: val_acc improved from 0.31080 to 0.31359, saving model to best_model.h5
# Epoch 184/500
# 403/403 [==============================] - 4s 9ms/step - loss: 2.0006 - acc: 0.3883 - val_loss: 2.6481 - val_acc: 0.3113
#
# Epoch 00184: val_acc did not improve from 0.31359
# Epoch 185/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9721 - acc: 0.3986 - val_loss: 2.6463 - val_acc: 0.3144
#
# Epoch 00185: val_acc improved from 0.31359 to 0.31445, saving model to best_model.h5
# Epoch 186/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.9781 - acc: 0.3997 - val_loss: 2.6464 - val_acc: 0.3092
#
# Epoch 00186: val_acc did not improve from 0.31445
# Epoch 187/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9870 - acc: 0.3924 - val_loss: 2.6584 - val_acc: 0.3015
#
# Epoch 00187: val_acc did not improve from 0.31445
# Epoch 188/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9839 - acc: 0.3946 - val_loss: 2.6551 - val_acc: 0.3051
#
# Epoch 00188: val_acc did not improve from 0.31445
# Epoch 189/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9793 - acc: 0.3953 - val_loss: 2.6503 - val_acc: 0.3082
#
# Epoch 00189: val_acc did not improve from 0.31445
# Epoch 190/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9827 - acc: 0.3945 - val_loss: 2.6486 - val_acc: 0.3094
#
# Epoch 00190: val_acc did not improve from 0.31445
# Epoch 191/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9841 - acc: 0.3959 - val_loss: 2.6390 - val_acc: 0.3103
#
# Epoch 00191: val_acc did not improve from 0.31445
# Epoch 192/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9804 - acc: 0.3963 - val_loss: 2.6409 - val_acc: 0.3134
#
# Epoch 00192: val_acc did not improve from 0.31445
# Epoch 193/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9697 - acc: 0.3979 - val_loss: 2.6428 - val_acc: 0.3121
#
# Epoch 00193: val_acc did not improve from 0.31445
# Epoch 194/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9728 - acc: 0.4002 - val_loss: 2.6355 - val_acc: 0.3111
#
# Epoch 00194: val_acc did not improve from 0.31445
# Epoch 195/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9853 - acc: 0.3924 - val_loss: 2.6662 - val_acc: 0.3066
#
# Epoch 00195: val_acc did not improve from 0.31445
# Epoch 196/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9851 - acc: 0.3927 - val_loss: 2.6498 - val_acc: 0.3099
#
# Epoch 00196: val_acc did not improve from 0.31445
# Epoch 197/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9851 - acc: 0.3949 - val_loss: 2.6488 - val_acc: 0.3136
#
# Epoch 00197: val_acc did not improve from 0.31445
# Epoch 198/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9665 - acc: 0.4008 - val_loss: 2.6484 - val_acc: 0.3137
#
# Epoch 00198: val_acc did not improve from 0.31445
# Epoch 199/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9876 - acc: 0.3968 - val_loss: 2.6463 - val_acc: 0.3064
#
# Epoch 00199: val_acc did not improve from 0.31445
# Epoch 200/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9746 - acc: 0.3970 - val_loss: 2.6535 - val_acc: 0.3129
#
# Epoch 00200: val_acc did not improve from 0.31445
# Epoch 201/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9788 - acc: 0.3970 - val_loss: 2.6381 - val_acc: 0.3112
#
# Epoch 00201: val_acc did not improve from 0.31445
# Epoch 202/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9537 - acc: 0.4053 - val_loss: 2.6471 - val_acc: 0.3092
#
# Epoch 00202: val_acc did not improve from 0.31445
# Epoch 203/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9756 - acc: 0.3989 - val_loss: 2.6444 - val_acc: 0.3103
#
# Epoch 00203: val_acc did not improve from 0.31445
# Epoch 204/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9801 - acc: 0.3990 - val_loss: 2.6364 - val_acc: 0.3117
#
# Epoch 00204: val_acc did not improve from 0.31445
# Epoch 205/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9601 - acc: 0.4019 - val_loss: 2.6521 - val_acc: 0.3141
#
# Epoch 00205: val_acc did not improve from 0.31445
# Epoch 206/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9886 - acc: 0.3979 - val_loss: 2.6542 - val_acc: 0.3103
#
# Epoch 00206: val_acc did not improve from 0.31445
# Epoch 207/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9842 - acc: 0.3912 - val_loss: 2.6462 - val_acc: 0.3091
#
# Epoch 00207: val_acc did not improve from 0.31445
# Epoch 208/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9672 - acc: 0.4035 - val_loss: 2.6352 - val_acc: 0.3148
#
# Epoch 00208: val_acc improved from 0.31445 to 0.31483, saving model to best_model.h5
# Epoch 209/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9628 - acc: 0.3996 - val_loss: 2.6517 - val_acc: 0.3089
#
# Epoch 00209: val_acc did not improve from 0.31483
# Epoch 210/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9643 - acc: 0.4016 - val_loss: 2.6311 - val_acc: 0.3134
#
# Epoch 00210: val_acc did not improve from 0.31483
# Epoch 211/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9636 - acc: 0.3958 - val_loss: 2.6578 - val_acc: 0.3122
#
# Epoch 00211: val_acc did not improve from 0.31483
# Epoch 212/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9417 - acc: 0.4050 - val_loss: 2.6511 - val_acc: 0.3210
#
# Epoch 00212: val_acc improved from 0.31483 to 0.32104, saving model to best_model.h5
# Epoch 213/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9549 - acc: 0.4063 - val_loss: 2.6528 - val_acc: 0.3115
#
# Epoch 00213: val_acc did not improve from 0.32104
# Epoch 214/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9629 - acc: 0.3992 - val_loss: 2.6399 - val_acc: 0.3173
#
# Epoch 00214: val_acc did not improve from 0.32104
# Epoch 215/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9625 - acc: 0.4006 - val_loss: 2.6596 - val_acc: 0.3155
#
# Epoch 00215: val_acc did not improve from 0.32104
# Epoch 216/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9624 - acc: 0.4031 - val_loss: 2.6559 - val_acc: 0.3129
#
# Epoch 00216: val_acc did not improve from 0.32104
# Epoch 217/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9569 - acc: 0.4029 - val_loss: 2.6544 - val_acc: 0.3109
#
# Epoch 00217: val_acc did not improve from 0.32104
# Epoch 218/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9690 - acc: 0.3994 - val_loss: 2.6462 - val_acc: 0.3143
#
# Epoch 00218: val_acc did not improve from 0.32104
# Epoch 219/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9694 - acc: 0.3992 - val_loss: 2.6562 - val_acc: 0.3104
#
# Epoch 00219: val_acc did not improve from 0.32104
# Epoch 220/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9754 - acc: 0.3979 - val_loss: 2.6464 - val_acc: 0.3107
#
# Epoch 00220: val_acc did not improve from 0.32104
# Epoch 221/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9497 - acc: 0.3984 - val_loss: 2.6542 - val_acc: 0.3158
#
# Epoch 00221: val_acc did not improve from 0.32104
# Epoch 222/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9604 - acc: 0.4064 - val_loss: 2.6490 - val_acc: 0.3150
#
# Epoch 00222: val_acc did not improve from 0.32104
# Epoch 223/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9722 - acc: 0.3999 - val_loss: 2.6491 - val_acc: 0.3157
#
# Epoch 00223: val_acc did not improve from 0.32104
# Epoch 224/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9611 - acc: 0.4012 - val_loss: 2.6522 - val_acc: 0.3119
#
# Epoch 00224: val_acc did not improve from 0.32104
# Epoch 225/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9538 - acc: 0.3987 - val_loss: 2.6417 - val_acc: 0.3141
#
# Epoch 00225: val_acc did not improve from 0.32104
# Epoch 226/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9572 - acc: 0.3998 - val_loss: 2.6409 - val_acc: 0.3165
#
# Epoch 00226: val_acc did not improve from 0.32104
# Epoch 227/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9707 - acc: 0.3968 - val_loss: 2.6485 - val_acc: 0.3134
#
# Epoch 00227: val_acc did not improve from 0.32104
# Epoch 228/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9538 - acc: 0.4003 - val_loss: 2.6405 - val_acc: 0.3158
#
# Epoch 00228: val_acc did not improve from 0.32104
# Epoch 229/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9549 - acc: 0.4003 - val_loss: 2.6442 - val_acc: 0.3142
#
# Epoch 00229: val_acc did not improve from 0.32104
# Epoch 230/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9771 - acc: 0.3937 - val_loss: 2.6454 - val_acc: 0.3127
#
# Epoch 00230: val_acc did not improve from 0.32104
# Epoch 231/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9501 - acc: 0.4075 - val_loss: 2.6579 - val_acc: 0.3103
#
# Epoch 00231: val_acc did not improve from 0.32104
# Epoch 232/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9395 - acc: 0.4043 - val_loss: 2.6508 - val_acc: 0.3195
#
# Epoch 00232: val_acc did not improve from 0.32104
# Epoch 233/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9434 - acc: 0.4030 - val_loss: 2.6469 - val_acc: 0.3210
#
# Epoch 00233: val_acc did not improve from 0.32104
# Epoch 234/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9456 - acc: 0.4025 - val_loss: 2.6519 - val_acc: 0.3204
#
# Epoch 00234: val_acc did not improve from 0.32104
# Epoch 235/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9353 - acc: 0.4050 - val_loss: 2.6555 - val_acc: 0.3176
#
# Epoch 00235: val_acc did not improve from 0.32104
# Epoch 236/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9467 - acc: 0.4084 - val_loss: 2.6470 - val_acc: 0.3165
#
# Epoch 00236: val_acc did not improve from 0.32104
# Epoch 237/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9579 - acc: 0.4025 - val_loss: 2.6505 - val_acc: 0.3172
#
# Epoch 00237: val_acc did not improve from 0.32104
# Epoch 238/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9419 - acc: 0.4032 - val_loss: 2.6509 - val_acc: 0.3186
#
# Epoch 00238: val_acc did not improve from 0.32104
# Epoch 239/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9497 - acc: 0.4063 - val_loss: 2.6498 - val_acc: 0.3101
#
# Epoch 00239: val_acc did not improve from 0.32104
# Epoch 240/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9331 - acc: 0.4068 - val_loss: 2.6380 - val_acc: 0.3180
#
# Epoch 00240: val_acc did not improve from 0.32104
# Epoch 241/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9271 - acc: 0.4096 - val_loss: 2.6487 - val_acc: 0.3097
#
# Epoch 00241: val_acc did not improve from 0.32104
# Epoch 242/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9408 - acc: 0.4058 - val_loss: 2.6437 - val_acc: 0.3165
#
# Epoch 00242: val_acc did not improve from 0.32104
# Epoch 243/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9349 - acc: 0.4070 - val_loss: 2.6480 - val_acc: 0.3134
#
# Epoch 00243: val_acc did not improve from 0.32104
# Epoch 244/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9523 - acc: 0.4034 - val_loss: 2.6440 - val_acc: 0.3148
#
# Epoch 00244: val_acc did not improve from 0.32104
# Epoch 245/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9360 - acc: 0.4080 - val_loss: 2.6451 - val_acc: 0.3160
#
# Epoch 00245: val_acc did not improve from 0.32104
# Epoch 246/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9383 - acc: 0.4084 - val_loss: 2.6487 - val_acc: 0.3093
#
# Epoch 00246: val_acc did not improve from 0.32104
# Epoch 247/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.9362 - acc: 0.4070 - val_loss: 2.6369 - val_acc: 0.3160
#
# ...
#
# Epoch 00416: val_acc did not improve from 0.33253
# Epoch 417/500
# 403/403 [==============================] - 4s 11ms/step - loss: 1.8530 - acc: 0.4283 - val_loss: 2.6344 - val_acc: 0.3304
#
# Epoch 00417: val_acc did not improve from 0.33253
# Epoch 418/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8674 - acc: 0.4260 - val_loss: 2.6406 - val_acc: 0.3208
#
# Epoch 00418: val_acc did not improve from 0.33253
# Epoch 419/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8702 - acc: 0.4249 - val_loss: 2.6403 - val_acc: 0.3248
#
# Epoch 00419: val_acc did not improve from 0.33253
# Epoch 420/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8840 - acc: 0.4199 - val_loss: 2.6317 - val_acc: 0.3261
#
# Epoch 00420: val_acc did not improve from 0.33253
# Epoch 421/500
# 403/403 [==============================] - 4s 11ms/step - loss: 1.8650 - acc: 0.4226 - val_loss: 2.6427 - val_acc: 0.3256
#
# Epoch 00421: val_acc did not improve from 0.33253
# Epoch 422/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8690 - acc: 0.4212 - val_loss: 2.6329 - val_acc: 0.3224
#
# Epoch 00422: val_acc did not improve from 0.33253
# Epoch 423/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8588 - acc: 0.4271 - val_loss: 2.6272 - val_acc: 0.3235
#
# Epoch 00423: val_acc did not improve from 0.33253
# Epoch 424/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8612 - acc: 0.4224 - val_loss: 2.6337 - val_acc: 0.3203
#
# Epoch 00424: val_acc did not improve from 0.33253
# Epoch 425/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8657 - acc: 0.4267 - val_loss: 2.6262 - val_acc: 0.3271
#
# Epoch 00425: val_acc did not improve from 0.33253
# Epoch 426/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8789 - acc: 0.4233 - val_loss: 2.6273 - val_acc: 0.3283
#
# Epoch 00426: val_acc did not improve from 0.33253
# Epoch 427/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8791 - acc: 0.4191 - val_loss: 2.6370 - val_acc: 0.3272
#
# Epoch 00427: val_acc did not improve from 0.33253
# Epoch 428/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8640 - acc: 0.4267 - val_loss: 2.6278 - val_acc: 0.3298
#
# Epoch 00428: val_acc did not improve from 0.33253
# Epoch 429/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8472 - acc: 0.4293 - val_loss: 2.6426 - val_acc: 0.3265
#
# Epoch 00429: val_acc did not improve from 0.33253
# Epoch 430/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8760 - acc: 0.4200 - val_loss: 2.6301 - val_acc: 0.3252
#
# Epoch 00430: val_acc did not improve from 0.33253
# Epoch 431/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8633 - acc: 0.4242 - val_loss: 2.6510 - val_acc: 0.3260
#
# Epoch 00431: val_acc did not improve from 0.33253
# Epoch 432/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8686 - acc: 0.4232 - val_loss: 2.6276 - val_acc: 0.3320
#
# Epoch 00432: val_acc did not improve from 0.33253
# Epoch 433/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8659 - acc: 0.4281 - val_loss: 2.6369 - val_acc: 0.3261
#
# Epoch 00433: val_acc did not improve from 0.33253
# Epoch 434/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8555 - acc: 0.4261 - val_loss: 2.6351 - val_acc: 0.3271
#
# Epoch 00434: val_acc did not improve from 0.33253
# Epoch 435/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8680 - acc: 0.4215 - val_loss: 2.6260 - val_acc: 0.3262
#
# Epoch 00435: val_acc did not improve from 0.33253
# Epoch 436/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8641 - acc: 0.4278 - val_loss: 2.6314 - val_acc: 0.3252
#
# Epoch 00436: val_acc did not improve from 0.33253
# Epoch 437/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8810 - acc: 0.4216 - val_loss: 2.6226 - val_acc: 0.3269
#
# Epoch 00437: val_acc did not improve from 0.33253
# Epoch 438/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8571 - acc: 0.4294 - val_loss: 2.6349 - val_acc: 0.3266
#
# Epoch 00438: val_acc did not improve from 0.33253
# Epoch 439/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8620 - acc: 0.4208 - val_loss: 2.6391 - val_acc: 0.3293
#
# Epoch 00439: val_acc did not improve from 0.33253
# Epoch 440/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8648 - acc: 0.4237 - val_loss: 2.6515 - val_acc: 0.3275
#
# Epoch 00440: val_acc did not improve from 0.33253
# Epoch 441/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8659 - acc: 0.4239 - val_loss: 2.6499 - val_acc: 0.3280
#
# Epoch 00441: val_acc did not improve from 0.33253
# Epoch 442/500
# 403/403 [==============================] - 4s 11ms/step - loss: 1.8633 - acc: 0.4273 - val_loss: 2.6378 - val_acc: 0.3318
#
# Epoch 00442: val_acc did not improve from 0.33253
# Epoch 443/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8654 - acc: 0.4218 - val_loss: 2.6480 - val_acc: 0.3248
#
# Epoch 00443: val_acc did not improve from 0.33253
# Epoch 444/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8651 - acc: 0.4266 - val_loss: 2.6335 - val_acc: 0.3295
#
# Epoch 00444: val_acc did not improve from 0.33253
# Epoch 445/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8779 - acc: 0.4214 - val_loss: 2.6367 - val_acc: 0.3283
#
# Epoch 00445: val_acc did not improve from 0.33253
# Epoch 446/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8579 - acc: 0.4272 - val_loss: 2.6315 - val_acc: 0.3276
#
# Epoch 00446: val_acc did not improve from 0.33253
# Epoch 447/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8594 - acc: 0.4276 - val_loss: 2.6430 - val_acc: 0.3292
#
# Epoch 00447: val_acc did not improve from 0.33253
# Epoch 448/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8614 - acc: 0.4232 - val_loss: 2.6247 - val_acc: 0.3332
#
# Epoch 00448: val_acc improved from 0.33253 to 0.33323, saving model to best_model.h5
# Epoch 449/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8571 - acc: 0.4263 - val_loss: 2.6357 - val_acc: 0.3300
#
# Epoch 00449: val_acc did not improve from 0.33323
# Epoch 450/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8617 - acc: 0.4273 - val_loss: 2.6427 - val_acc: 0.3304
#
# Epoch 00450: val_acc did not improve from 0.33323
# Epoch 451/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8628 - acc: 0.4262 - val_loss: 2.6435 - val_acc: 0.3283
#
# Epoch 00451: val_acc did not improve from 0.33323
# Epoch 452/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8590 - acc: 0.4281 - val_loss: 2.6426 - val_acc: 0.3262
#
# Epoch 00452: val_acc did not improve from 0.33323
# Epoch 453/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8525 - acc: 0.4255 - val_loss: 2.6356 - val_acc: 0.3339
#
# Epoch 00453: val_acc improved from 0.33323 to 0.33385, saving model to best_model.h5
# Epoch 454/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8616 - acc: 0.4300 - val_loss: 2.6474 - val_acc: 0.3329
#
# Epoch 00454: val_acc did not improve from 0.33385
# Epoch 455/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8572 - acc: 0.4247 - val_loss: 2.6404 - val_acc: 0.3281
#
# Epoch 00455: val_acc did not improve from 0.33385
# Epoch 456/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8552 - acc: 0.4226 - val_loss: 2.6359 - val_acc: 0.3314
#
# Epoch 00456: val_acc did not improve from 0.33385
# Epoch 457/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8643 - acc: 0.4224 - val_loss: 2.6328 - val_acc: 0.3304
#
# Epoch 00457: val_acc did not improve from 0.33385
# Epoch 458/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8679 - acc: 0.4272 - val_loss: 2.6397 - val_acc: 0.3338
#
# Epoch 00458: val_acc did not improve from 0.33385
# Epoch 459/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8631 - acc: 0.4259 - val_loss: 2.6296 - val_acc: 0.3331
#
# Epoch 00459: val_acc did not improve from 0.33385
# Epoch 460/500
# 403/403 [==============================] - 4s 9ms/step - loss: 1.8429 - acc: 0.4293 - val_loss: 2.6347 - val_acc: 0.3304
#
# Epoch 00460: val_acc did not improve from 0.33385
# Epoch 461/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8652 - acc: 0.4237 - val_loss: 2.6420 - val_acc: 0.3298
#
# Epoch 00461: val_acc did not improve from 0.33385
# Epoch 462/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8629 - acc: 0.4252 - val_loss: 2.6423 - val_acc: 0.3287
#
# Epoch 00462: val_acc did not improve from 0.33385
# Epoch 463/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8601 - acc: 0.4281 - val_loss: 2.6262 - val_acc: 0.3328
#
# Epoch 00463: val_acc did not improve from 0.33385
# Epoch 464/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8509 - acc: 0.4279 - val_loss: 2.6363 - val_acc: 0.3272
#
# Epoch 00464: val_acc did not improve from 0.33385
# Epoch 465/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8679 - acc: 0.4260 - val_loss: 2.6450 - val_acc: 0.3275
#
# Epoch 00465: val_acc did not improve from 0.33385
# Epoch 466/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8482 - acc: 0.4296 - val_loss: 2.6385 - val_acc: 0.3318
#
# Epoch 00466: val_acc did not improve from 0.33385
# Epoch 467/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8495 - acc: 0.4298 - val_loss: 2.6282 - val_acc: 0.3294
#
# Epoch 00467: val_acc did not improve from 0.33385
# Epoch 468/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8561 - acc: 0.4308 - val_loss: 2.6438 - val_acc: 0.3258
#
# Epoch 00468: val_acc did not improve from 0.33385
# Epoch 469/500
# 403/403 [==============================] - 4s 11ms/step - loss: 1.8649 - acc: 0.4264 - val_loss: 2.6190 - val_acc: 0.3286
#
# Epoch 00469: val_acc did not improve from 0.33385
# Epoch 470/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8506 - acc: 0.4270 - val_loss: 2.6221 - val_acc: 0.3329
#
# Epoch 00470: val_acc did not improve from 0.33385
# Epoch 471/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8615 - acc: 0.4277 - val_loss: 2.6375 - val_acc: 0.3260
#
# Epoch 00471: val_acc did not improve from 0.33385
# Epoch 472/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8602 - acc: 0.4257 - val_loss: 2.6296 - val_acc: 0.3307
#
# Epoch 00472: val_acc did not improve from 0.33385
# Epoch 473/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8609 - acc: 0.4252 - val_loss: 2.6179 - val_acc: 0.3303
#
# Epoch 00473: val_acc did not improve from 0.33385
# Epoch 474/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8662 - acc: 0.4279 - val_loss: 2.6394 - val_acc: 0.3261
#
# Epoch 00474: val_acc did not improve from 0.33385
# Epoch 475/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8595 - acc: 0.4289 - val_loss: 2.6207 - val_acc: 0.3295
#
# Epoch 00475: val_acc did not improve from 0.33385
# Epoch 476/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8575 - acc: 0.4264 - val_loss: 2.6311 - val_acc: 0.3262
#
# Epoch 00476: val_acc did not improve from 0.33385
# Epoch 477/500
# 403/403 [==============================] - 4s 11ms/step - loss: 1.8564 - acc: 0.4290 - val_loss: 2.6343 - val_acc: 0.3246
#
# Epoch 00477: val_acc did not improve from 0.33385
# Epoch 478/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8426 - acc: 0.4320 - val_loss: 2.6271 - val_acc: 0.3280
#
# Epoch 00478: val_acc did not improve from 0.33385
# Epoch 479/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8529 - acc: 0.4268 - val_loss: 2.6312 - val_acc: 0.3351
#
# Epoch 00479: val_acc improved from 0.33385 to 0.33509, saving model to best_model.h5
# Epoch 480/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8482 - acc: 0.4260 - val_loss: 2.6295 - val_acc: 0.3305
#
# Epoch 00480: val_acc did not improve from 0.33509
# Epoch 481/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8555 - acc: 0.4264 - val_loss: 2.6382 - val_acc: 0.3310
#
# Epoch 00481: val_acc did not improve from 0.33509
# Epoch 482/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8563 - acc: 0.4261 - val_loss: 2.6282 - val_acc: 0.3318
#
# Epoch 00482: val_acc did not improve from 0.33509
# Epoch 483/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8711 - acc: 0.4221 - val_loss: 2.6346 - val_acc: 0.3339
#
# Epoch 00483: val_acc did not improve from 0.33509
# Epoch 484/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8437 - acc: 0.4296 - val_loss: 2.6357 - val_acc: 0.3338
#
# Epoch 00484: val_acc did not improve from 0.33509
# Epoch 485/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8577 - acc: 0.4269 - val_loss: 2.6395 - val_acc: 0.3338
#
# Epoch 00485: val_acc did not improve from 0.33509
# Epoch 486/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8555 - acc: 0.4285 - val_loss: 2.6231 - val_acc: 0.3300
#
# Epoch 00486: val_acc did not improve from 0.33509
# Epoch 487/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8610 - acc: 0.4269 - val_loss: 2.6287 - val_acc: 0.3300
#
# Epoch 00487: val_acc did not improve from 0.33509
# Epoch 488/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8363 - acc: 0.4290 - val_loss: 2.6332 - val_acc: 0.3293
#
# Epoch 00488: val_acc did not improve from 0.33509
# Epoch 489/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8693 - acc: 0.4242 - val_loss: 2.6295 - val_acc: 0.3293
#
# Epoch 00489: val_acc did not improve from 0.33509
# Epoch 490/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8547 - acc: 0.4237 - val_loss: 2.6330 - val_acc: 0.3314
#
# Epoch 00490: val_acc did not improve from 0.33509
# Epoch 491/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8623 - acc: 0.4254 - val_loss: 2.6408 - val_acc: 0.3299
#
# Epoch 00491: val_acc did not improve from 0.33509
# Epoch 492/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8486 - acc: 0.4316 - val_loss: 2.6362 - val_acc: 0.3259
#
# Epoch 00492: val_acc did not improve from 0.33509
# Epoch 493/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8504 - acc: 0.4263 - val_loss: 2.6166 - val_acc: 0.3374
#
# Epoch 00493: val_acc improved from 0.33509 to 0.33742, saving model to best_model.h5
# Epoch 494/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8512 - acc: 0.4271 - val_loss: 2.6312 - val_acc: 0.3355
#
# Epoch 00494: val_acc did not improve from 0.33742
# Epoch 495/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8599 - acc: 0.4269 - val_loss: 2.6419 - val_acc: 0.3336
#
# Epoch 00495: val_acc did not improve from 0.33742
# Epoch 496/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8569 - acc: 0.4271 - val_loss: 2.6295 - val_acc: 0.3338
#
# Epoch 00496: val_acc did not improve from 0.33742
# Epoch 497/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8581 - acc: 0.4240 - val_loss: 2.6281 - val_acc: 0.3304
#
# Epoch 00497: val_acc did not improve from 0.33742
# Epoch 498/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8594 - acc: 0.4253 - val_loss: 2.6431 - val_acc: 0.3293
#
# Epoch 00498: val_acc did not improve from 0.33742
# Epoch 499/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8552 - acc: 0.4280 - val_loss: 2.6364 - val_acc: 0.3287
#
# Epoch 00499: val_acc did not improve from 0.33742
# Epoch 500/500
# 403/403 [==============================] - 4s 10ms/step - loss: 1.8538 - acc: 0.4276 - val_loss: 2.6205 - val_acc: 0.3358
#
# Epoch 00500: val_acc did not improve from 0.33742

# %%
#loading best model
from keras.models import load_model
model = load_model('best_model.h5')

# %%
import random
ind = np.random.randint(0,len(x_val)-1)

random_music = x_val[ind]

predictions=[]
for i in range(10):

    random_music = random_music.reshape(1,no_of_timesteps)

    prob  = model.predict(random_music)[0]
    y_pred= np.argmax(prob,axis=0)
    predictions.append(y_pred)

    random_music = np.insert(random_music[0],len(random_music[0]),y_pred)
    random_music = random_music[1:]
    
print(predictions)
# Out:
# [150, 76, 150, 117, 140, 140, 140, 140, 140, 76]

# %%
x_int_to_note = dict((number, note_) for number, note_ in enumerate(unique_x)) 
predicted_notes = [x_int_to_note[i] for i in predictions]

# %%
def convert_to_midi(prediction_output):
   
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                
                cn=int(current_note)
                new_note = note.Note(cn)
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
                
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
            
        # pattern is a note
        else:
            
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 1
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='music.mid')

# %%
convert_to_midi(predicted_notes)
